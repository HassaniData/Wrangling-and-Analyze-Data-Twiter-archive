# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# ## We Rate Dogs Insights

# %% [markdown]
# #### A Twitter account with funny or interesting facts and pictures about dogs (mainly)…

# %% [markdown]
# Insight 1 and visualizations: Pupper is the most popular Dog stage, with a frequency of 66%. Floofer is the least popular, with a frequency of less than 1%.
# The following bar chart illustrates the popularity of different Dog stages, with Pupper being the most popular and Floofer being the least popular.

# %% [markdown]
# ![Dog%20stages.png](attachment:Dog%20stages.png)

# %% [markdown]
# Insight 2: Charlie is the most used Dog name, with a relatively high frequency regarding the other names.

# %% [markdown]
# ![popular%20dogs%20names.png](attachment:popular%20dogs%20names.png)

# %% [markdown]
# Insight 3: The ten least used Dog names are Gilbert, Eevee, ED, Philbert, Jeffrie, Herschel, Lolo, Thor, Kathie, and Rilo, with a frequency of less than 1% each.

# %% [markdown]
# ![least%20used%20dog%20names.png](attachment:least%20used%20dog%20names.png)

# %% [markdown]
# In conclusion, the analysis of Dog stages and names on Twitter reveals that Pupper is the most popular stage, with Floofer being the least popular. Charlie is the most used Dog name, and the ten least used Dog names are Gilbert, Eevee, ED, Philbert, Jeffrie, Herschel, Lolo, Thor, Kathie, and Rilo. This information can be useful for dog breeders, pet stores, and anyone interested in popular dog names and stages
